# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import csv

# %%
np.logspace(np.log10(20),np.log10(20000),20)
# Out:
# array([   20.        ,    28.76899777,    41.38276162,    59.52702883,
#           85.62664797,   123.16964221,   177.17335808,   254.85499714,
#          366.59614217,   527.33017975,   758.53803815,  1091.11895623,
#         1569.5199407 ,  2257.67578337,  3247.55347838,  4671.44293818,
#         6719.63657257,  9665.86047714, 13903.85592355, 20000.        ])

# %%
with open("src-tauri/fft_output.txt",'r') as file:
    data = list(csv.reader(file))
    data_format = [float(x[0]) for x in data ]
    plt.plot(data_format[:32000])

# %%
plt.plot(vec)

# %%
vec2 = [
    7.399425,
    3.1904323,
    2.4779131,
    4.140637,
    0.9267687,
    0.48738122,
    0.30907068,
    0.2148196,
    0.1579512,
    0.1207104,
    0.09494533,
    0.076463714,
    0.06296247,
    0.053159393,
    0.04638579,
    0.042361043,
    0.041018963,
    0.042361066,
    0.046385825,
    0.05315956,
    0.06296247,
    0.076463714,
    0.094945356,
    0.12071048,
    0.1579512,
    0.21481954,
    0.30907068,
    0.48738116,
    0.9267687,
    4.140637,
    2.4779131,
    3.1904323,
    3.028308,
    6.168763,
    2.0806463,
    4.1041346,
    0.9870209,
    0.58905745,
    0.42978314,
    0.34474343,
    0.29250515,
    0.25773013,
    0.23345447,
    0.21607819,
    0.20358117,
    0.19476217,
    0.18888691,
    0.18551502,
    0.18441808,
    0.18551502,
    0.18888685,
    0.1947622,
    0.20358117,
    0.21607803,
    0.23345447,
    0.2577302,
    0.29250515,
    0.34474343,
    0.4297831,
    0.5890574,
    0.9870209,
    4.1041346,
    2.0806463,
    6.168763,
]

# %%
plt.plot(vec2)
